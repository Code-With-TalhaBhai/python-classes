# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
diamonds = diamonds.head()
display(diamonds.count())
diamonds
# Out:
# carat      5
# cut        5
# color      5
# clarity    5
# depth      5
# table      5
# price      5
# x          5
# y          5
# z          5
# dtype: int64
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.histplot(diamonds['price'])
plt.show()

# %%
import pandas as pd
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')

# %% [markdown]
# #### Show Frequency Polygon

# %%
sns.histplot(data=diamonds,x=diamonds['price'],kde=True)
plt.show()

# %%
sns.histplot(data=diamonds,x=diamonds['price'],kde=True,color="red")
plt.show()
