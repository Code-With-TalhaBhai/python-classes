# %% [markdown]
# ## Pandas
#
# * Filtering
# * Sorting
# * Useful Methods
# * GroupBy
# * Merge

# %%
import pandas as pd

# Define the data as a list of dictionaries with 10 student records
students_data = [
    {'roll_no': 1, 'name': 'Alice', 'father': 'Bob', 'course': 'Physics', 'date_of_admission': '2023-01-10', 'fee': 10000},
    {'roll_no': 2, 'name': 'Brian', 'father': 'Steve', 'course': 'Chemistry', 'date_of_admission': '2023-02-12', 'fee': 11000},
    {'roll_no': 3, 'name': 'Chloe', 'father': 'Tim', 'course': 'Biology', 'date_of_admission': '2023-03-14', 'fee': 12000},
    {'roll_no': 4, 'name': 'David', 'father': 'Rick', 'course': 'Mathematics', 'date_of_admission': '2023-04-10', 'fee': 13000},
    {'roll_no': 5, 'name': 'Eva', 'father': 'John', 'course': 'Computer Science', 'date_of_admission': '2023-05-16', 'fee': 14000},
    {'roll_no': 6, 'name': 'Frank', 'father': 'Tom', 'course': 'Economics', 'date_of_admission': '2023-06-21', 'fee': 15000},
    {'roll_no': 7, 'name': 'Grace', 'father': 'Harry', 'course': 'History', 'date_of_admission': '2023-07-25', 'fee': 16000},
    {'roll_no': 8, 'name': 'Henry', 'father': 'Charles', 'course': 'Geography', 'date_of_admission': '2023-08-17', 'fee': 17000},
    {'roll_no': 9, 'name': 'Isabel', 'father': 'Oliver', 'course': 'English', 'date_of_admission': '2023-09-10', 'fee': 18000},
    {'roll_no': 10, 'name': 'Jack', 'father': 'Noah', 'course': 'Art', 'date_of_admission': '2023-10-05', 'fee': 19000},
]

df = pd.DataFrame(students_data)
display(df)
df.info()
# Out:
#    roll_no    name   father            course date_of_admission    fee
# 0        1   Alice      Bob           Physics        2023-01-10  10000
# 1        2   Brian    Steve         Chemistry        2023-02-12  11000
# 2        3   Chloe      Tim           Biology        2023-03-14  12000
# 3        4   David     Rick       Mathematics        2023-04-10  13000
# 4        5     Eva     John  Computer Science        2023-05-16  14000
# 5        6   Frank      Tom         Economics        2023-06-21  15000
# 6        7   Grace    Harry           History        2023-07-25  16000
# 7        8   Henry  Charles         Geography        2023-08-17  17000
# 8        9  Isabel   Oliver           English        2023-09-10  18000
# 9       10    Jack     Noah               Art        2023-10-05  19000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ...

# %%
import pandas as pd

# Changing the data type of date_of_admission to datetime
students_data = [
    {'roll_no': 1, 'name': 'Alice', 'father': 'Bob', 'course': 'Physics', 'date_of_admission': '2023-01-10', 'fee': 10000},
    {'roll_no': 2, 'name': 'Brian', 'father': 'Steve', 'course': 'Chemistry', 'date_of_admission': '2023-02-12', 'fee': 11000},
    {'roll_no': 3, 'name': 'Chloe', 'father': 'Tim', 'course': 'Biology', 'date_of_admission': '2023-03-14', 'fee': 12000},
    {'roll_no': 4, 'name': 'David', 'father': 'Rick', 'course': 'Mathematics', 'date_of_admission': '2023-04-10', 'fee': 13000},
    {'roll_no': 5, 'name': 'Eva', 'father': 'John', 'course': 'Computer Science', 'date_of_admission': '2023-05-16', 'fee': 14000},
    {'roll_no': 6, 'name': 'Frank', 'father': 'Tom', 'course': 'Economics', 'date_of_admission': '2023-06-21', 'fee': 15000},
    {'roll_no': 7, 'name': 'Grace', 'father': 'Harry', 'course': 'History', 'date_of_admission': '2023-07-25', 'fee': 16000},
    {'roll_no': 8, 'name': 'Henry', 'father': 'Charles', 'course': 'Geography', 'date_of_admission': '2023-08-17', 'fee': 17000},
    {'roll_no': 9, 'name': 'Isabel', 'father': 'Oliver', 'course': 'English', 'date_of_admission': '2023-09-10', 'fee': 18000},
    {'roll_no': 10, 'name': 'Jack', 'father': 'Noah', 'course': 'Art', 'date_of_admission': '2023-10-05', 'fee': 19000},
]
df['date_of_admission'] = pd.to_datetime(df['date_of_admission'])
display(df)
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#       3 # Changing the data type of date_of_admission to datetime
#       4 students_data = [
#       5     {'roll_no': 1, 'name': 'Alice', 'father': 'Bob', 'course': 'Physics', 'date_of_admission': '2023-01-10', 'fee': 10000},
#       6     {'roll_no': 2, 'name': 'Brian', 'father': 'Steve', 'course': 'Chemistry', 'date_of_admission': '2023-02-12', 'fee': 11000},
#    (...)
#      14     {'roll_no': 10, 'name': 'Jack', 'father': 'Noah', 'course': 'Art', 'date_of_admission': '2023-10-05', 'fee': 19000},
#      15 ]
# ---> 16 df['date_of_admission'] = pd.to_datetime(df['date_of_admission'])
#      17 display(df)
#      18 df.info()
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Pandera is a data-validator for Pandas

# %%
# %pip install pandera
# Out:
# ...
#   Obtaining dependency information for pandera from https://files.pythonhosted.org/packages/f5/2b/c01ef6aad281332f2628a4ae9c3cd8ba6fd632e547e9a645ffe18aeaa94f/pandera-0.18.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for multimethod from https://files.pythonhosted.org/packages/7f/bd/750245e47e7f307d9f94d4fa84727f4ed9956005dfa671d58be1d531a0f6/multimethod-1.10-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pydantic from https://files.pythonhosted.org/packages/dd/b7/9aea7ee6c01fe3f3c03b8ca3c7797c866df5fecece9d6cb27caa138db2e2/pydantic-2.5.3-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/65.6 kB ? eta -:--:--
#      ------------------ --------------------- 30.7/65.6 kB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 65.6/65.6 kB 1.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pandera as pa
from datetime import datetime

# Define the data as a list of dictionaries with 10 student records
students_data = [
    {'roll_no': 1, 'name': 'Alice', 'father': 'Bob', 'course': 'Physics', 'date_of_admission': '2023-01-10', 'fee': 10000},
    {'roll_no': 2, 'name': 'Brian', 'father': 'Steve', 'course': 'Chemistry', 'date_of_admission': '2023-02-12', 'fee': 11000},
    {'roll_no': 3, 'name': 'Chloe', 'father': 'Tim', 'course': 'Biology', 'date_of_admission': '2023-03-14', 'fee': 12000},
    {'roll_no': 4, 'name': 'Henry', 'father': 'Rick', 'course': 'Mathematics', 'date_of_admission': '2023-04-10', 'fee': 13000},
    {'roll_no': 5, 'name': 'Eva', 'father': 'John', 'course': 'Computer Science', 'date_of_admission': '2023-05-16', 'fee': 14000},
    {'roll_no': 6, 'name': 'Frank', 'father': 'Tom', 'course': 'Economics', 'date_of_admission': '2023-06-21', 'fee': 15000},
    {'roll_no': 7, 'name': 'Grace', 'father': 'Harry', 'course': 'History', 'date_of_admission': '2023-07-25', 'fee': 16000},
    {'roll_no': 8, 'name': 'Henry', 'father': 'Charles', 'course': 'Geography', 'date_of_admission': '2023-08-17', 'fee': 17000},
    {'roll_no': 9, 'name': 'Isabel', 'father': 'Oliver', 'course': 'English', 'date_of_admission': '2023-09-10', 'fee': 18000},
    {'roll_no': 10, 'name': 'Jack', 'father': 'Noah', 'course': 'Art', 'date_of_admission': '2023-10-05', 'fee': 19000},
    {'roll_no': 11, 'name': 'Jackel', 'father': 'Noah', 'course': 'Art', 'date_of_admission': '2023-10-05', 'fee': 19000},
    {'roll_no': 12, 'name': 'Bob', 'father': 'ubam', 'course': 'art', 'date_of_admission': '2023-10-05', 'fee': 19000},
    {'roll_no': 13, 'name': 'Hawk', 'father': 'Noah', 'course': 'Art', 'date_of_admission': '2023-10-05', 'fee': 19000},
    {'roll_no': 14, 'name': 'Grace', 'father': 'Harry', 'course': 'History', 'date_of_admission': '2023-07-25', 'fee': 16000},
    {'roll_no': 15, 'name': 'Eva', 'father': 'Johnny', 'course': 'Medical Science', 'date_of_admission': '2023-05-16', 'fee': 14000},
]

df_Schema = pa.DataFrameSchema({
    "roll_no": pa.Column(int,checks=pa.Check.ge(1)),
    "name": pa.Column(str,checks=pa.Check.str_length(3,8),nullable=False),
    "father": pa.Column(str,checks=pa.Check.str_length(3,8)),
    "course": pa.Column(str,checks=pa.Check.str_length(3,20)),
    "date_of_admission": pa.Column(checks=pa.Check.le(datetime.now())),
    "fee": pa.Column(int,checks=pa.Check.ge(1000))
})

df = pd.DataFrame(students_data)

df['date_of_admission'] = pd.to_datetime(df['date_of_admission'])

validated_df = df_Schema(df)
validated_df
# Out:
#     roll_no    name   father            course date_of_admission    fee
# 0         1   Alice      Bob           Physics        2023-01-10  10000
# 1         2   Brian    Steve         Chemistry        2023-02-12  11000
# 2         3   Chloe      Tim           Biology        2023-03-14  12000
# 3         4   Henry     Rick       Mathematics        2023-04-10  13000
# 4         5     Eva     John  Computer Science        2023-05-16  14000
# 5         6   Frank      Tom         Economics        2023-06-21  15000
# 6         7   Grace    Harry           History        2023-07-25  16000
# 7         8   Henry  Charles         Geography        2023-08-17  17000
# 8         9  Isabel   Oliver           English        2023-09-10  18000
# 9        10    Jack     Noah               Art        2023-10-05  19000
# 10       11  Jackel     Noah               Art        2023-10-05  19000
# 11       12     Bob     ubam               art        2023-10-05  19000
# ...

# %%
df.head(3)
# Out:
#    roll_no   name father     course date_of_admission    fee
# 0        1  Alice    Bob    Physics        2023-01-10  10000
# 1        2  Brian  Steve  Chemistry        2023-02-12  11000
# 2        3  Chloe    Tim    Biology        2023-03-14  12000

# %% [markdown]
# ### Applying Filters on DataFrame

# %%
df.name.value_counts()
# Out:
# name
# Henry     2
# Alice     1
# Brian     1
# Chloe     1
# Eva       1
# Frank     1
# Grace     1
# Isabel    1
# Jack      1
# Name: count, dtype: int64

# %%
df.course.value_counts()
# Out:
# course
# Art                 4
# Physics             1
# Chemistry           1
# Biology             1
# Mathematics         1
# Computer Science    1
# Economics           1
# History             1
# Geography           1
# English             1
# Name: count, dtype: int64

# %%
df.course.value_counts(dropna=False) # Also counts rows which has missing values
# Out:
# course
# Art                 4
# Physics             1
# Chemistry           1
# Biology             1
# Mathematics         1
# Computer Science    1
# Economics           1
# History             1
# Geography           1
# English             1
# Name: count, dtype: int64

# %%
# Normalize to find proportion between 0 and 1
df.course.value_counts(dropna=False,normalize=True)
# Out:
# course
# Art                 0.266667
# Computer Science    0.133333
# History             0.133333
# Physics             0.066667
# Chemistry           0.066667
# Biology             0.066667
# Mathematics         0.066667
# Economics           0.066667
# Geography           0.066667
# English             0.066667
# Name: proportion, dtype: float64

# %%
# To find Percentage
df.course.value_counts(dropna=False,normalize=True)*100
# Out:
# course
# Art                 26.666667
# Computer Science    13.333333
# History             13.333333
# Physics              6.666667
# Chemistry            6.666667
# Biology              6.666667
# Mathematics          6.666667
# Economics            6.666667
# Geography            6.666667
# English              6.666667
# Name: proportion, dtype: float64

# %%
import pandas as pd
import numpy as np
# timedelta is used to perform operations on datetime
from datetime import datetime,timedelta

# Set a seed for reproductibility
np.random.seed(0)

no_of_transactions = 10

current_year = datetime.now().year
start_date = datetime(current_year,1,1)
end_date = datetime.now()


random_dates = [start_date + timedelta(days=np.random.randint(0,(end_date-start_date).days)) for _ in range(no_of_transactions)]

random_fees = np.random.randint(1000,5000,no_of_transactions)


fee_transaction = pd.DataFrame({
     'Fees':random_fees,
     'Date':random_dates
    })

# fee_transaction = pd.DataFrame({
#     'fee':random_fees,'dates':random_dates
#     })


# Sort by date for readability
fee_transaction.sort_values('Date',inplace=True)
display(fee_transaction)
print("============================")
# Reset index after sorting
fee_transaction.reset_index(drop=True,inplace=True)
fee_transaction
# Out:
#    Fees       Date
# 8  3362 2023-01-10
# 1  2778 2023-02-17
# 2  2828 2023-04-28
# 0  1277 2023-06-22
# 3  3647 2023-07-12
# 6  3648 2023-07-15
# 9  1705 2023-07-31
# 5  4544 2023-09-09
# 4  4142 2023-11-20
# 7  4468 2023-12-26
# ...
#    Fees       Date
# 0  3362 2023-01-10
# 1  2778 2023-02-17
# 2  2828 2023-04-28
# 3  1277 2023-06-22
# 4  3647 2023-07-12
# 5  3648 2023-07-15
# 6  1705 2023-07-31
# 7  4544 2023-09-09
# 8  4142 2023-11-20
# 9  4468 2023-12-26

# %%
# cut() is used to divide data into discrete intervals or categories
pd.cut(fee_transaction['Fees'],[1000,2000,3000,4000,5000])
# Out:
# 0    (3000, 4000]
# 1    (2000, 3000]
# 2    (3000, 4000]
# 3    (2000, 3000]
# 4    (4000, 5000]
# 5    (4000, 5000]
# 6    (1000, 2000]
# 7    (3000, 4000]
# 8    (4000, 5000]
# 9    (4000, 5000]
# Name: Fees, dtype: category
# Categories (4, interval[int64, right]): [(1000, 2000] < (2000, 3000] < (3000, 4000] < (4000, 5000]]

# %%
pd.cut(fee_transaction['Fees'],[1000,2000,3000,4000,5000]).value_counts()
# Out:
# Fees
# (4000, 5000]    4
# (3000, 4000]    3
# (2000, 3000]    2
# (1000, 2000]    1
# Name: count, dtype: int64

# %%
# To find percentage
pd.cut(fee_transaction['Fees'],[1000,2000,3000,4000,5000]).value_counts(normalize=True)*100
# Out:
# Fees
# (4000, 5000]    40.0
# (3000, 4000]    30.0
# (2000, 3000]    20.0
# (1000, 2000]    10.0
# Name: proportion, dtype: float64

# %%
# To find Quantiles
pd.qcut(fee_transaction['Fees'],[0,.25,.5,.75,1])
# Out:
# 0      (2961.5, 3647.5]
# 1    (1704.999, 2961.5]
# 2      (2961.5, 3647.5]
# 3    (1704.999, 2961.5]
# 4      (3647.5, 4386.5]
# 5      (4386.5, 4558.0]
# 6    (1704.999, 2961.5]
# 7      (3647.5, 4386.5]
# 8      (4386.5, 4558.0]
# 9      (4386.5, 4558.0]
# Name: Fees, dtype: category
# Categories (4, interval[float64, right]): [(1704.999, 2961.5] < (2961.5, 3647.5] < (3647.5, 4386.5] < (4386.5, 4558.0]]

# %%
pd.qcut(fee_transaction['Fees'],[0,.25,.5,.75,1]).value_counts(normalize=True)*100
# Out:
# Fees
# (1704.999, 2961.5]    30.0
# (4386.5, 4558.0]      30.0
# (2961.5, 3647.5]      20.0
# (3647.5, 4386.5]      20.0
# Name: proportion, dtype: float64

# %%
# Back to first df
df.head()
# Out:
#    roll_no   name father            course date_of_admission    fee
# 0        1  Alice    Bob           Physics        2023-01-10  10000
# 1        2  Brian  Steve         Chemistry        2023-02-12  11000
# 2        3  Chloe    Tim           Biology        2023-03-14  12000
# 3        4  Henry   Rick       Mathematics        2023-04-10  13000
# 4        5    Eva   John  Computer Science        2023-05-16  14000

# %% [markdown]
# #### Filtering on Columns
#
# * &
# * |
# * ~
#
# Apply Operations on these types of columns
#
# * Numerical Column -> df['num_col']
# * String Column -> df['str_col'].str()
# * DateTime Column -> df['datetime_col'].dt()

# %%
df['course'] == 'Art'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# 14    False
# Name: course, dtype: bool

# %%
df[df['course'] == 'Art']
# Out:
#     roll_no    name father course date_of_admission    fee
# 9        10    Jack   Noah    Art        2023-10-05  19000
# 10       11  Jackel   Noah    Art        2023-10-05  19000
# 11       12     Bob   ubam    Art        2023-10-05  19000
# 12       13    Hawk   Noah    Art        2023-10-05  19000

# %%
df['course'].str.lower() == 'art'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# 14    False
# Name: course, dtype: bool

# %%
df[df['course'].str.lower() == 'art']
# Out:
#     roll_no    name father course date_of_admission    fee
# 9        10    Jack   Noah    Art        2023-10-05  19000
# 10       11  Jackel   Noah    Art        2023-10-05  19000
# 11       12     Bob   ubam    art        2023-10-05  19000
# 12       13    Hawk   Noah    Art        2023-10-05  19000

# %%
df['course'].str.contains('cs')
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: course, dtype: bool

# %%
df[df['course'].str.contains('cs')]
# Out:
#    roll_no   name father       course date_of_admission    fee
# 0        1  Alice    Bob      Physics        2023-01-10  10000
# 3        4  Henry   Rick  Mathematics        2023-04-10  13000
# 5        6  Frank    Tom    Economics        2023-06-21  15000

# %%
df[df['course'].str.contains('cs') & df['course'].str.contains('ma')]
# Out:
#    roll_no   name father       course date_of_admission    fee
# 3        4  Henry   Rick  Mathematics        2023-04-10  13000

# %%
df[df['course'].str.contains('cs') | df['course'].str.contains('ce') | (df['fee']>13000)]
# Out:
#     roll_no    name   father            course date_of_admission    fee
# 0         1   Alice      Bob           Physics        2023-01-10  10000
# 3         4   Henry     Rick       Mathematics        2023-04-10  13000
# 4         5     Eva     John  Computer Science        2023-05-16  14000
# 5         6   Frank      Tom         Economics        2023-06-21  15000
# 6         7   Grace    Harry           History        2023-07-25  16000
# 7         8   Henry  Charles         Geography        2023-08-17  17000
# 8         9  Isabel   Oliver           English        2023-09-10  18000
# 9        10    Jack     Noah               Art        2023-10-05  19000
# 10       11  Jackel     Noah               Art        2023-10-05  19000
# 11       12     Bob     ubam               art        2023-10-05  19000
# 12       13    Hawk     Noah               Art        2023-10-05  19000
# 13       14   Grace    Harry           History        2023-07-25  16000
# ...

# %%
# Checking String col methods
[i for i in dir(df['course'].str) if "_" not in i]
# Out:
# ['capitalize',
#  'casefold',
#  'cat',
#  'center',
#  'contains',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'extract',
#  'extractall',
#  'find',
#  'findall',
#  'fullmatch',
#  'get',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'islower',
#  'isnumeric',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'len',
#  'ljust',
#  'lower',
#  'lstrip',
#  'match',
#  'normalize',
#  'pad',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'repeat',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'slice',
#  'split',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'wrap',
#  'zfill']

# %%
# Checking DateTime functions 
[i for i in dir(df['date_of_admission'].dt) if "_" not in i]
# Out:
# ['ceil',
#  'date',
#  'day',
#  'dayofweek',
#  'dayofyear',
#  'daysinmonth',
#  'floor',
#  'freq',
#  'hour',
#  'isocalendar',
#  'microsecond',
#  'minute',
#  'month',
#  'nanosecond',
#  'normalize',
#  'quarter',
#  'round',
#  'second',
#  'strftime',
#  'time',
#  'timetz',
#  'tz',
#  'unit',
#  'weekday',
#  'year']

# %%
df['date_of_admission']
# Out:
# 0    2023-01-10
# 1    2023-02-12
# 2    2023-03-14
# 3    2023-04-10
# 4    2023-05-16
# 5    2023-06-21
# 6    2023-07-25
# 7    2023-08-17
# 8    2023-09-10
# 9    2023-10-05
# 10   2023-10-05
# 11   2023-10-05
# 12   2023-10-05
# 13   2023-07-25
# 14   2023-05-16
# Name: date_of_admission, dtype: datetime64[ns]

# %%
df['date_of_admission'].dt.year
df['date_of_admission'].dt.month
df['date_of_admission'].dt.day
df['date_of_admission'].dt.weekday
df['date_of_admission'].dt.day_of_week
df['date_of_admission'].dt.hour
df['date_of_admission'].dt.minute
df['date_of_admission'].dt.second
df['date_of_admission'].dt.microsecond
df['date_of_admission'].dt.tz
df['date_of_admission'].dt.tz_localize
df['date_of_admission'].dt.tz_convert
df['date_of_admission'].dt.tz_localize(None)
# Out:
# 0    2023-01-10
# 1    2023-02-12
# 2    2023-03-14
# 3    2023-04-10
# 4    2023-05-16
# 5    2023-06-21
# 6    2023-07-25
# 7    2023-08-17
# 8    2023-09-10
# 9    2023-10-05
# 10   2023-10-05
# 11   2023-10-05
# 12   2023-10-05
# 13   2023-07-25
# 14   2023-05-16
# Name: date_of_admission, dtype: datetime64[ns]

# %%
from datetime import datetime

date = datetime.now()
date
# Out:
# datetime.datetime(2023, 12, 25, 7, 46, 49, 157934)

# %% [markdown]
# #### Apply Filter on date column
#
# dataframe.column.dt
# * dt.strftime(Give New Format to DateTime and convert it into fstring)
# * dt.strptime(Parse String and convert it into DateTime object)
#
# Below are some of the commonly used format codes:
#
# * %a - Abbreviated weekday name.
# * %A - Full weekday name.
# * %w - Weekday as a decimal number, where 0 is Sunday and 6 is Saturday.
# * %d - Day of the month as a zero-padded decimal number.
# * %b - Abbreviated month name.
# * %B - Full month name.
# * %m - Month as a zero-padded decimal number.
# * %y - Year without century as a zero-padded decimal number.
# * %Y - Year with century as a decimal number.
# * %H - Hour (24-hour clock) as a zero-padded decimal number.
# * %I - Hour (12-hour clock) as a zero-padded decimal number.
# * %p - Locale’s equivalent of either AM or PM.
# * %M - Minute as a zero-padded decimal number.
# * %S - Second as a zero-padded decimal number.
# * %f - Microsecond as a decimal number, zero-padded on the left.
# * %z - UTC offset in the form ±HHMM[SS[.ffffff]] (empty string if the object is naive).
# * %Z - Time zone name (empty string if the object is naive).
# * %j - Day of the year as a zero-padded decimal number.
# * %U - Week number of the year (Sunday as the first day of the week) as a zero-padded decimal number.
# * %W - Week number of the year (Monday as the first day of the week) as a zero-padded decimal number.
# * %c - Locale’s appropriate date and time representation.
# * %x - Locale’s appropriate date representation.
# * %X - Locale’s appropriate time representation.
# * %G - ISO 8601 year with century representing the year that contains the greater part of the ISO week (%V).
# * %u - ISO 8601 weekday as a decimal number where 1 is Monday.
# * %V - ISO 8601 week number as a decimal number with Monday as the first day of the week.

# %%
# strftime -> To Format Time (Only Apply on Series)
import pandas as pd
from datetime import datetime

s1 = pd.Series(datetime.now())
display(s1.dt.strftime("%Y %A, %b %d"))
s1.dt.strftime("%d %b, %Y   %A")
# Out:
# 0    2023 Sunday, Dec 31
# dtype: object
# 0    31 Dec, 2023   Sunday
# dtype: object

# %%
df['date_of_admission'] = df['date_of_admission'].dt.strftime("%d %b, %Y(%A)")
df
# Out:
#     roll_no    name   father            course        date_of_admission    fee
# 0         1   Alice      Bob           Physics    10 Jan, 2023(Tuesday)  10000
# 1         2   Brian    Steve         Chemistry     12 Feb, 2023(Sunday)  11000
# 2         3   Chloe      Tim           Biology    14 Mar, 2023(Tuesday)  12000
# 3         4   Henry     Rick       Mathematics     10 Apr, 2023(Monday)  13000
# 4         5     Eva     John  Computer Science    16 May, 2023(Tuesday)  14000
# 5         6   Frank      Tom         Economics  21 Jun, 2023(Wednesday)  15000
# 6         7   Grace    Harry           History    25 Jul, 2023(Tuesday)  16000
# 7         8   Henry  Charles         Geography   17 Aug, 2023(Thursday)  17000
# 8         9  Isabel   Oliver           English     10 Sep, 2023(Sunday)  18000
# 9        10    Jack     Noah               Art   05 Oct, 2023(Thursday)  19000
# 10       11  Jackel     Noah               Art   05 Oct, 2023(Thursday)  19000
# ...

# %%
from datetime import datetime
s2 = pd.Series(['10 Jan 2023','12 Feb 2003','14 Mar 2016'])

# apply function to apply custom function in pandas
s2.apply(lambda x: datetime.strptime(x,"%d %b %Y") ) # string to datetime
s2
# Out:
# 0    10 Jan 2023
# 1    12 Feb 2003
# 2    14 Mar 2016
# dtype: object

# %% [markdown]
# ## Group-By
#
# * dataframe.groupby(['col1','col2'])
# * dataframe.groupby(['col1','col2'])[['col1,'col2']].aggregate([min,max])
# * dateframe.groupby(['col1','col2'])[['col1','col2']].apply(function())

# %%
import pandas as pd
import pandera as pa
from datetime import datetime

# Define the data as a list of dictionaries with 10 student records
students_data = [
    {'roll_no': 1, 'name': 'Alice', 'father': 'Bob', 'course': 'Physics', 'date_of_admission': '2023-01-10', 'fee': 10000},
    {'roll_no': 2, 'name': 'Brian', 'father': 'Steve', 'course': 'Chemistry', 'date_of_admission': '2023-08-17', 'fee': 11000},
    {'roll_no': 3, 'name': 'Chloe', 'father': 'Tim', 'course': 'Biology', 'date_of_admission': '2023-03-14', 'fee': 12000},
    {'roll_no': 4, 'name': 'Henry', 'father': 'Rick', 'course': 'Mathematics', 'date_of_admission': '2021-11-05', 'fee': 13000},
    {'roll_no': 5, 'name': 'Eva', 'father': 'John', 'course': 'Computer Science', 'date_of_admission': '2023-05-16', 'fee': 14000},
    {'roll_no': 6, 'name': 'Frank', 'father': 'Tom', 'course': 'Economics', 'date_of_admission': '2023-06-21', 'fee': 15000},
    {'roll_no': 7, 'name': 'Grace', 'father': 'Harry', 'course': 'History', 'date_of_admission': '2023-01-10', 'fee': 16000},
    {'roll_no': 8, 'name': 'Henry', 'father': 'Charles', 'course': 'Geography', 'date_of_admission': '2023-08-17', 'fee': 17000},
    {'roll_no': 9, 'name': 'Isabel', 'father': 'Oliver', 'course': 'English', 'date_of_admission': '2023-09-10', 'fee': 18000},
    {'roll_no': 10, 'name': 'Jack', 'father': 'Noah', 'course': 'Art', 'date_of_admission': '2023-10-05', 'fee': 19000},
    {'roll_no': 11, 'name': 'Jackel', 'father': 'Noah', 'course': 'Art', 'date_of_admission': '2023-9-05', 'fee': 19000},
    {'roll_no': 12, 'name': 'Bob', 'father': 'ubam', 'course': 'art', 'date_of_admission': '2021-11-05', 'fee': 19000},
    {'roll_no': 13, 'name': 'Hawk', 'father': 'Noah', 'course': 'Art', 'date_of_admission': '2020-8-05', 'fee': 19000},
    {'roll_no': 14, 'name': 'Grace', 'father': 'Harry', 'course': 'History', 'date_of_admission': '2023-01-10', 'fee': 16000},
    {'roll_no': 15, 'name': 'Eva', 'father': 'Johnny', 'course': 'Medical Science', 'date_of_admission': '2023-05-16', 'fee': 14000},
]

df_Schema = pa.DataFrameSchema({
    "roll_no": pa.Column(int,checks=pa.Check.ge(1)),
    "name": pa.Column(str,checks=pa.Check.str_length(3,8),nullable=False),
    "father": pa.Column(str,checks=pa.Check.str_length(3,8)),
    "course": pa.Column(str,checks=pa.Check.str_length(3,20)),
    "date_of_admission": pa.Column(checks=pa.Check.le(datetime.now())),
    "fee": pa.Column(int,checks=pa.Check.ge(1000))
})

df = pd.DataFrame(students_data)

df['date_of_admission'] = pd.to_datetime(df['date_of_admission'])

validated_df = df_Schema(df)
validated_df
# Out:
#     roll_no    name   father            course date_of_admission    fee
# 0         1   Alice      Bob           Physics        2023-01-10  10000
# 1         2   Brian    Steve         Chemistry        2023-08-17  11000
# 2         3   Chloe      Tim           Biology        2023-03-14  12000
# 3         4   Henry     Rick       Mathematics        2021-11-05  13000
# 4         5     Eva     John  Computer Science        2023-05-16  14000
# 5         6   Frank      Tom         Economics        2023-06-21  15000
# 6         7   Grace    Harry           History        2023-01-10  16000
# 7         8   Henry  Charles         Geography        2023-08-17  17000
# 8         9  Isabel   Oliver           English        2023-09-10  18000
# 9        10    Jack     Noah               Art        2023-10-05  19000
# 10       11  Jackel     Noah               Art        2023-09-05  19000
# 11       12     Bob     ubam               art        2021-11-05  19000
# ...

# %%
list(df.groupby(['course'])) # Return Array of Tuples
# Out:
# [(('Art',),
#       roll_no    name father course date_of_admission    fee
#   9        10    Jack   Noah    Art        2023-10-05  19000
#   10       11  Jackel   Noah    Art        2023-10-05  19000
#   12       13    Hawk   Noah    Art        2023-10-05  19000),
#  (('Biology',),
#      roll_no   name father   course date_of_admission    fee
#   2        3  Chloe    Tim  Biology        2023-03-14  12000),
#  (('Chemistry',),
#      roll_no   name father     course date_of_admission    fee
#   1        2  Brian  Steve  Chemistry        2023-02-12  11000),
#  (('Computer Science',),
#      roll_no name father            course date_of_admission    fee
#   4        5  Eva   John  Computer Science        2023-05-16  14000),
#  (('Economics',),
#      roll_no   name father     course date_of_admission    fee
#   5        6  Frank    Tom  Economics        2023-06-21  15000),
#  (('English',),
#      roll_no    name  father   course date_of_admission    fee
# ...

# %%
for group in list(df.groupby(['course'])):
    display(group[0])
    display(group[1])
# Out:
# ('Art',)
#    roll_no  name father course date_of_admission    fee
# 9       10  Jack   Noah    Art        2023-10-05  19000
# ('Biology',)
#    roll_no   name father   course date_of_admission    fee
# 2        3  Chloe    Tim  Biology        2023-03-14  12000
# ('Chemistry',)
#    roll_no   name father     course date_of_admission    fee
# 1        2  Brian  Steve  Chemistry        2023-02-12  11000
# ('Computer Science',)
#    roll_no name father            course date_of_admission    fee
# 4        5  Eva   John  Computer Science        2023-05-16  14000
# ('Economics',)
#    roll_no   name father     course date_of_admission    fee
# 5        6  Frank    Tom  Economics        2023-06-21  15000
# ('English',)
#    roll_no    name  father   course date_of_admission    fee
# 8        9  Isabel  Oliver  English        2023-09-10  18000
# ('Geography',)
#    roll_no   name   father     course date_of_admission    fee
# 7        8  Henry  Charles  Geography        2023-08-17  17000
# ...

# %%
# for group in list(df.groupby(['course'])):
for group in list(df.groupby(['course'])):
    display(group[0][0])
    display(group[1])
# Out:
# 'Art'
#     roll_no    name father course date_of_admission    fee
# 9        10    Jack   Noah    Art        2023-10-05  19000
# 10       11  Jackel   Noah    Art        2023-10-05  19000
# 12       13    Hawk   Noah    Art        2023-10-05  19000
# 'Biology'
#    roll_no   name father   course date_of_admission    fee
# 2        3  Chloe    Tim  Biology        2023-03-14  12000
# 'Chemistry'
#    roll_no   name father     course date_of_admission    fee
# 1        2  Brian  Steve  Chemistry        2023-02-12  11000
# 'Computer Science'
#    roll_no name father            course date_of_admission    fee
# 4        5  Eva   John  Computer Science        2023-05-16  14000
# 'Economics'
#    roll_no   name father     course date_of_admission    fee
# 5        6  Frank    Tom  Economics        2023-06-21  15000
# 'English'
#    roll_no    name  father   course date_of_admission    fee
# 8        9  Isabel  Oliver  English        2023-09-10  18000
# 'Geography'
# ...

# %%
for group in list(df.groupby(df['date_of_admission'])):
    display(group[0])
    display(group[1])
# Out:
# Timestamp('2020-08-05 00:00:00')
#     roll_no  name father course date_of_admission    fee
# 12       13  Hawk   Noah    Art        2020-08-05  19000
# Timestamp('2021-11-05 00:00:00')
#     roll_no   name father       course date_of_admission    fee
# 3         4  Henry   Rick  Mathematics        2021-11-05  13000
# 11       12    Bob   ubam          art        2021-11-05  19000
# Timestamp('2023-01-10 00:00:00')
#     roll_no   name father   course date_of_admission    fee
# 0         1  Alice    Bob  Physics        2023-01-10  10000
# 6         7  Grace  Harry  History        2023-01-10  16000
# 13       14  Grace  Harry  History        2023-01-10  16000
# Timestamp('2023-03-14 00:00:00')
#    roll_no   name father   course date_of_admission    fee
# 2        3  Chloe    Tim  Biology        2023-03-14  12000
# Timestamp('2023-05-16 00:00:00')
#     roll_no name  father            course date_of_admission    fee
# ...

# %%
for group in list(df.groupby(df['date_of_admission'].dt.strftime('%B'))):
    display(group[0])
    display(group[1])
# Out:
# 'August'
#     roll_no   name   father     course date_of_admission    fee
# 1         2  Brian    Steve  Chemistry        2023-08-17  11000
# 7         8  Henry  Charles  Geography        2023-08-17  17000
# 12       13   Hawk     Noah        Art        2020-08-05  19000
# 'January'
#     roll_no   name father   course date_of_admission    fee
# 0         1  Alice    Bob  Physics        2023-01-10  10000
# 6         7  Grace  Harry  History        2023-01-10  16000
# 13       14  Grace  Harry  History        2023-01-10  16000
# 'June'
#    roll_no   name father     course date_of_admission    fee
# 5        6  Frank    Tom  Economics        2023-06-21  15000
# 'March'
#    roll_no   name father   course date_of_admission    fee
# 2        3  Chloe    Tim  Biology        2023-03-14  12000
# 'May'
#     roll_no name  father            course date_of_admission    fee
# 4         5  Eva    John  Computer Science        2023-05-16  14000
# ...

# %%
for group in list(df.groupby([df['date_of_admission'].dt.strftime("%B"),df['course']])):
    display(group[0])
    display(group[1])
# Out:
# ('August', 'Art')
#     roll_no  name father course date_of_admission    fee
# 12       13  Hawk   Noah    Art        2020-08-05  19000
# ('August', 'Chemistry')
#    roll_no   name father     course date_of_admission    fee
# 1        2  Brian  Steve  Chemistry        2023-08-17  11000
# ('August', 'Geography')
#    roll_no   name   father     course date_of_admission    fee
# 7        8  Henry  Charles  Geography        2023-08-17  17000
# ('January', 'History')
#     roll_no   name father   course date_of_admission    fee
# 6         7  Grace  Harry  History        2023-01-10  16000
# 13       14  Grace  Harry  History        2023-01-10  16000
# ('January', 'Physics')
#    roll_no   name father   course date_of_admission    fee
# 0        1  Alice    Bob  Physics        2023-01-10  10000
# ('June', 'Economics')
#    roll_no   name father     course date_of_admission    fee
# 5        6  Frank    Tom  Economics        2023-06-21  15000
# ('March', 'Biology')
# ...

# %%
df.groupby([df['course']]).aggregate('count')
# Out:
#                   roll_no  name  father  date_of_admission  fee
# course
# Art                     3     3       3                  3    3
# Biology                 1     1       1                  1    1
# Chemistry               1     1       1                  1    1
# Computer Science        1     1       1                  1    1
# Economics               1     1       1                  1    1
# English                 1     1       1                  1    1
# Geography               1     1       1                  1    1
# History                 2     2       2                  2    2
# Mathematics             1     1       1                  1    1
# Medical Science         1     1       1                  1    1
# Physics                 1     1       1                  1    1
# art                     1     1       1                  1    1

# %%
display(df['fee'].min())
display(df['fee'].max())
display(df['fee'].mean())
display(df['fee'].median())
display(df['fee'].count())
display(df['fee'].sum())
# Out:
# 10000
# 19000
# 15466.666666666666
# 16000.0
# 15
# 232000

# %% [markdown]
# `agg():` Allows applying multiple aggregation functions simultaneously or specific functions to specific columns.

# %%
df.agg({'fee':'mean','roll_no':'sum'})
# Out:
# fee        15466.666667
# roll_no      120.000000
# dtype: float64

# %%
df.groupby(['course','fee'])['fee'].agg(['mean','min','max'])
# Out:
#                            mean    min    max
# course           fee
# Art              19000  19000.0  19000  19000
# Biology          12000  12000.0  12000  12000
# Chemistry        11000  11000.0  11000  11000
# Computer Science 14000  14000.0  14000  14000
# Economics        15000  15000.0  15000  15000
# English          18000  18000.0  18000  18000
# Geography        17000  17000.0  17000  17000
# History          16000  16000.0  16000  16000
# Mathematics      13000  13000.0  13000  13000
# Medical Science  14000  14000.0  14000  14000
# Physics          10000  10000.0  10000  10000
# art              19000  19000.0  19000  19000

# %%
# Showing 5 rows of each group(e.g Art has 3 records)
df.groupby(df['course']).apply(lambda x : x.head())
# Out:
#                      roll_no    name   father            course  \
# course
# Art              9        10    Jack     Noah               Art
#                  10       11  Jackel     Noah               Art
#                  12       13    Hawk     Noah               Art
# Biology          2         3   Chloe      Tim           Biology
# Chemistry        1         2   Brian    Steve         Chemistry
# Computer Science 4         5     Eva     John  Computer Science
# Economics        5         6   Frank      Tom         Economics
# English          8         9  Isabel   Oliver           English
# Geography        7         8   Henry  Charles         Geography
# History          6         7   Grace    Harry           History
#                  13       14   Grace    Harry           History
# Mathematics      3         4   Henry     Rick       Mathematics
# Medical Science  14       15     Eva   Johnny   Medical Science
# ...

# %%
# Showing single record of every group
df.groupby(df['course']).apply(lambda x : x.head(1))
# Out:
#                      roll_no    name   father            course  \
# course
# Art              9        10    Jack     Noah               Art
# Biology          2         3   Chloe      Tim           Biology
# Chemistry        1         2   Brian    Steve         Chemistry
# Computer Science 4         5     Eva     John  Computer Science
# Economics        5         6   Frank      Tom         Economics
# English          8         9  Isabel   Oliver           English
# Geography        7         8   Henry  Charles         Geography
# History          6         7   Grace    Harry           History
# Mathematics      3         4   Henry     Rick       Mathematics
# Medical Science  14       15     Eva   Johnny   Medical Science
# Physics          0         1   Alice      Bob           Physics
# art              11       12     Bob     ubam               art
#
#                     date_of_admission    fee
# course
# Art              9         2023-10-05  19000
# ...

# %% [markdown]
# ### Data Visulaization

# %%
df['course'].value_counts()
# Out:
# course
# Art                 3
# History             2
# Physics             1
# Chemistry           1
# Biology             1
# Mathematics         1
# Computer Science    1
# Economics           1
# Geography           1
# English             1
# art                 1
# Medical Science     1
# Name: count, dtype: int64

# %%
df['fee'].value_counts()
# Out:
# fee
# 19000    4
# 14000    2
# 16000    2
# 10000    1
# 11000    1
# 12000    1
# 13000    1
# 15000    1
# 17000    1
# 18000    1
# Name: count, dtype: int64

# %%
# %pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/2e/51/c77a14869b7eb9d6fb440e811b754fc3950d6868c38ace57d0632b674415/matplotlib-3.8.2-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/8e/ae/a6353db548bff1a592b85ae6bb80275f0a51dc25a0410d059e5b33183e36/contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/31/ec/1aeea536f14a03dd26679d7bfeb9b164379009afb71086476816d7a6ea8c/fonttools-4.47.0-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
# ...

# %%
df['fee'].value_counts().plot()
# Out:
# <Axes: xlabel='fee'>

# %%
df['fee'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='fee'>

# %%
df['fee'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['fee'].value_counts(normalize=True).plot(kind='pie')
# Out:
# <Axes: ylabel='proportion'>

# %%
df['fee'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='fee'>

# %%
df.groupby(['course'])['fee'].agg(['mean','min','max']).plot(kind='bar')
# Out:
# <Axes: xlabel='course'>

# %% [markdown]
# ## Data Wrangling
#
# `Data wrangling is the process of converting raw data into a usable form. It may also be called data munging or data remediation.`
#
# * .merge
# * .join
# * pd.concat(['df1','df2'])
#
#
# ### Joining
#
# * left join
# * right join
# * inner join
# * outer join
# * cross join
#
# https://www.w3schools.com/sql/sql_join.asp

# %%
import pandas as pd
from typing import Dict, Union, List

# Sample data for the 'students' DataFrame
students_data : Dict[str,List[Union[str,int]]] = {
    'student_id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'teacher_id': [101, 102, 103, 101, 102]
}
students : pd.DataFrame = pd.DataFrame(students_data)

# Sample data for the 'teachers' DataFrame
teachers_data : Dict[str,List[Union[str,int]]] ={
    'teacher_id': [101, 102, 103],
    'course_name':['Physics', 'Chem','Maths'],
    'teacher_name': ['Mr. Smith', 'Ms. Johnson', 'Dr. Lee']
}
teachers = pd.DataFrame(teachers_data)

# Sample data for the 'student_fees' DataFrame
student_fees_data : Dict[str,List[Union[str,int]]] = {
    'student_id': [1, 2, 3, 4, 5],
    'fee_paid': [1500, 1500, 1500, 1500, 1500]
}
student_fees = pd.DataFrame(student_fees_data)

# %% [markdown]
# ### Joining Column Properties
#
# * Same pattern of both columns
# * Same Data types of both columns
# * Column names can be different
#
#
# #### Merge
#
# * on
# * left_on
# * right_on
# * left_index=True
# * right_index=True
# * how

# %%
display(students)
display(teachers)
display(student_fees)
# Out:
#    student_id     name  teacher_id
# 0           1    Alice         101
# 1           2      Bob         102
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         102
#    teacher_id course_name teacher_name
# 0         101     Physics    Mr. Smith
# 1         102        Chem  Ms. Johnson
# 2         103       Maths      Dr. Lee
#    student_id  fee_paid
# 0           1      1500
# 1           2      1500
# 2           3      1500
# 3           4      1500
# 4           5      1500

# %%
# By-default `Inner Join`
df1 = pd.merge(students,teachers, on="teacher_id")
display(students)
display(teachers)
df1
# Out:
#    student_id     name  teacher_id
# 0           1    Alice         101
# 1           2      Bob         105
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         102
#    teacher_id course_name teacher_name
# 0         101     Physics    Mr. Smith
# 1         102        Chem  Ms. Johnson
# 2         101       Maths      Dr. Lee
#    student_id   name  teacher_id course_name teacher_name
# 0           1  Alice         101     Physics    Mr. Smith
# 1           1  Alice         101       Maths      Dr. Lee
# 2           4  David         101     Physics    Mr. Smith
# 3           4  David         101       Maths      Dr. Lee
# 4           5    Eva         102        Chem  Ms. Johnson

# %%
import pandas as pd
from typing import Dict, Union, List

# Sample data for the 'students' DataFrame
students_data : Dict[str,List[Union[str,int]]] = {
    'student_id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'teacher_id': [101, 105, 103, 101, 102]
}
students : pd.DataFrame = pd.DataFrame(students_data)

# Sample data for the 'teachers' DataFrame
teachers_data : Dict[str,List[Union[str,int]]] ={
    'teacher_id': [101, 102, 101],
    'course_name':['Physics', 'Chem','Maths'],
    'teacher_name': ['Mr. Smith', 'Ms. Johnson', 'Dr. Lee']
}
teachers = pd.DataFrame(teachers_data)

# Sample data for the 'student_fees' DataFrame
student_fees_data : Dict[str,List[Union[str,int]]] = {
    'student_id': [1, 2, 3, 4, 5],
    'fee_paid': [1500, 1500, 1500, 1500, 1500]
}
student_fees = pd.DataFrame(student_fees_data)

# %%
df1 = pd.merge(students,teachers,on="teacher_id", how="left")
display(students,teachers)
df1
# Out:
#    student_id     name  teacher_id
# 0           1    Alice         101
# 1           2      Bob         105
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         102
#    teacher_id course_name teacher_name
# 0         101     Physics    Mr. Smith
# 1         102        Chem  Ms. Johnson
# 2         101       Maths      Dr. Lee
#    student_id     name  teacher_id course_name teacher_name
# 0           1    Alice         101     Physics    Mr. Smith
# 1           1    Alice         101       Maths      Dr. Lee
# 2           2      Bob         105         NaN          NaN
# 3           3  Charlie         103         NaN          NaN
# 4           4    David         101     Physics    Mr. Smith
# 5           4    David         101       Maths      Dr. Lee
# 6           5      Eva         102        Chem  Ms. Johnson

# %%
df1 = pd.merge(students,teachers,on="teacher_id", how="right")
display(teachers,students)
df1
# Out:
#    teacher_id course_name teacher_name
# 0         101     Physics    Mr. Smith
# 1         102        Chem  Ms. Johnson
# 2         101       Maths      Dr. Lee
#    student_id     name  teacher_id
# 0           1    Alice         101
# 1           2      Bob         105
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         102
#    student_id   name  teacher_id course_name teacher_name
# 0           1  Alice         101     Physics    Mr. Smith
# 1           4  David         101     Physics    Mr. Smith
# 2           5    Eva         102        Chem  Ms. Johnson
# 3           1  Alice         101       Maths      Dr. Lee
# 4           4  David         101       Maths      Dr. Lee

# %%
df1 = pd.merge(students,teachers,on="teacher_id", how="outer")
display(teachers,students)
df1
# Out:
#    teacher_id course_name teacher_name
# 0         101     Physics    Mr. Smith
# 1         102        Chem  Ms. Johnson
# 2         101       Maths      Dr. Lee
#    student_id     name  teacher_id
# 0           1    Alice         101
# 1           2      Bob         105
# 2           3  Charlie         103
# 3           4    David         101
# 4           5      Eva         102
#    student_id     name  teacher_id course_name teacher_name
# 0           1    Alice         101     Physics    Mr. Smith
# 1           1    Alice         101       Maths      Dr. Lee
# 2           4    David         101     Physics    Mr. Smith
# 3           4    David         101       Maths      Dr. Lee
# 4           2      Bob         105         NaN          NaN
# 5           3  Charlie         103         NaN          NaN
# 6           5      Eva         102        Chem  Ms. Johnson

# %%
df1 : pd.DataFrame = pd.merge(students, teachers , how='cross')
df1
# Out:
#     student_id     name  teacher_id_x  teacher_id_y course_name teacher_name
# 0            1    Alice           101           101     Physics    Mr. Smith
# 1            1    Alice           101           102        Chem  Ms. Johnson
# 2            1    Alice           101           101       Maths      Dr. Lee
# 3            2      Bob           105           101     Physics    Mr. Smith
# 4            2      Bob           105           102        Chem  Ms. Johnson
# 5            2      Bob           105           101       Maths      Dr. Lee
# 6            3  Charlie           103           101     Physics    Mr. Smith
# 7            3  Charlie           103           102        Chem  Ms. Johnson
# 8            3  Charlie           103           101       Maths      Dr. Lee
# 9            4    David           101           101     Physics    Mr. Smith
# 10           4    David           101           102        Chem  Ms. Johnson
# ...

# %% [markdown]
# #### If column names are different

# %%
import pandas as pd
from typing import Dict, Union, List

# Sample data for the 'students' DataFrame
students_data : Dict[str,List[Union[str,int]]] = {
    'student_id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'teacher_id': [101, 105, 103, 101, 102]
}
students : pd.DataFrame = pd.DataFrame(students_data)

# Sample data for the 'teachers' DataFrame
teachers_data : Dict[str,List[Union[str,int]]] ={
    't_id': [101, 102, 101],
    'course_name':['Physics', 'Chem','Maths'],
    'teacher_name': ['Mr. Smith', 'Ms. Johnson', 'Dr. Lee']
}
teachers = pd.DataFrame(teachers_data)

# Sample data for the 'student_fees' DataFrame
student_fees_data : Dict[str,List[Union[str,int]]] = {
    'student_id': [1, 2, 3, 4, 5],
    'fee_paid': [1500, 1500, 1500, 1500, 1500]
}
student_fees = pd.DataFrame(student_fees_data)

# %%
df3 = pd.merge(students,teachers,left_on="teacher_id",right_on="t_id")
df3
# Out:
#    student_id   name  teacher_id  t_id course_name teacher_name
# 0           1  Alice         101   101     Physics    Mr. Smith
# 1           1  Alice         101   101       Maths      Dr. Lee
# 2           4  David         101   101     Physics    Mr. Smith
# 3           4  David         101   101       Maths      Dr. Lee
# 4           5    Eva         102   102        Chem  Ms. Johnson

# %%
pd.concat([students,teachers,student_fees]) # left-to-right(by-default)
# Out:
#    student_id     name  teacher_id   t_id course_name teacher_name  fee_paid
# 0         1.0    Alice       101.0    NaN         NaN          NaN       NaN
# 1         2.0      Bob       105.0    NaN         NaN          NaN       NaN
# 2         3.0  Charlie       103.0    NaN         NaN          NaN       NaN
# 3         4.0    David       101.0    NaN         NaN          NaN       NaN
# 4         5.0      Eva       102.0    NaN         NaN          NaN       NaN
# 0         NaN      NaN         NaN  101.0     Physics    Mr. Smith       NaN
# 1         NaN      NaN         NaN  102.0        Chem  Ms. Johnson       NaN
# 2         NaN      NaN         NaN  101.0       Maths      Dr. Lee       NaN
# 0         1.0      NaN         NaN    NaN         NaN          NaN    1500.0
# 1         2.0      NaN         NaN    NaN         NaN          NaN    1500.0
# 2         3.0      NaN         NaN    NaN         NaN          NaN    1500.0
# ...

# %%
pd.concat([students,teachers,student_fees],axis=1) # left-to-right
# Out:
#    student_id     name  teacher_id   t_id course_name teacher_name  \
# 0           1    Alice         101  101.0     Physics    Mr. Smith
# 1           2      Bob         105  102.0        Chem  Ms. Johnson
# 2           3  Charlie         103  101.0       Maths      Dr. Lee
# 3           4    David         101    NaN         NaN          NaN
# 4           5      Eva         102    NaN         NaN          NaN
#
#    student_id  fee_paid
# 0           1      1500
# 1           2      1500
# 2           3      1500
# 3           4      1500
# 4           5      1500
